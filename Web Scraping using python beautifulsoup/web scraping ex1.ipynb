# %%
import requests
from bs4 import BeautifulSoup

# %%
url="https://nznativeplantnursery.co.nz/shop/"
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<!--\n>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>\nSimple. by Sara (saratusar.com, @saratusar) for Innovatif - an awesome Slovenia-based digital agency (innovatif.com/en)\nChange it, enhance it and most importantly enjoy it!\n>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>\n-->\n\n<!--[if !IE]><!-->\n<html lang="en-NZ">\n<!--<![endif]-->\n<!--[if IE 6 ]><html lang="en-NZ" class="ie ie6"><![endif]-->\n<!--[if IE 7 ]><html lang="en-NZ" class="ie ie7"><![endif]-->\n<!--[if IE 8 ]><html lang="en-NZ" class="ie ie8"><![endif]-->\n<head>\n\t<base href="https://nznativeplantnursery.co.nz/"><!--[if lte IE 6]></base><![endif]-->\n\t<title>Shop &raquo; NZ Native Plant Nursery</title>\n\t<meta charset="utf-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0">\n\t<meta http-equiv="Content-Type" cont
# ...

# %%
soup = BeautifulSoup(page.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Simple. by Sara (saratusar.com, @saratusar) for Innovatif - an awesome Slovenia-based digital agency (innovatif.com/en)
# Change it, enhance it and most importantly enjoy it!
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# -->
# <!--[if !IE]><!-->
# <html lang="en-NZ">
#  <!--<![endif]-->
#  <!--[if IE 6 ]><html lang="en-NZ" class="ie ie6"><![endif]-->
#  <!--[if IE 7 ]><html lang="en-NZ" class="ie ie7"><![endif]-->
#  <!--[if IE 8 ]><html lang="en-NZ" class="ie ie8"><![endif]-->
#  <head>
#   <base href="https://nznativeplantnursery.co.nz/"/>
#   <!--[if lte IE 6]></base><![endif]-->
#   <title>
#    Shop » NZ Native Plant Nursery
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# ...

# %%
a=soup.find_all('div',class_='productImage')
a
# Out:
# [<div class="productImage">
#  <a ackama="" href="/shop/native-plants/caldcluvia-rosiflora/" rosifolia="" title="Click here to read more on ">
#  <img alt="Ackama rosifolia image" src="/assets/Uploads/8304aaac59/Calcluvia-rosiflora__FillWzQ4MCw2MDBd.jpg"/>
#  </a>
#  </div>, <div class="productImage">
#  <a anemanthele="" href="/shop/native-plants/anemanthele-lessoniana/" lessoniana="" title="Click here to read more on ">
#  <img alt="Anemanthele lessoniana image" src="/assets/Uploads/fce4c8773b/Anemanthele-lessoniana__FillWzQ4MCw2MDBd.JPG"/>
#  </a>
#  </div>, <div class="productImage">
#  <a apodasmia="" href="/shop/native-plants/apodasmia-similis/" similis="" title="Click here to read more on ">
#  <img alt="Apodasmia similis image" src="/assets/Uploads/552beadd3d/Apodasmia-1Lt__FillWzQ4MCw2MDBd.JPG"/>
#  </a>
#  </div>, <div class="productImage">
# ...

# %%
a=soup.find_all('a',title='Click here to read more on ')
a
# Out:
# [<a ackama="" href="/shop/native-plants/caldcluvia-rosiflora/" rosifolia="" title="Click here to read more on ">
#  <img alt="Ackama rosifolia image" src="/assets/Uploads/8304aaac59/Calcluvia-rosiflora__FillWzQ4MCw2MDBd.jpg"/>
#  </a>,
#  <a anemanthele="" href="/shop/native-plants/anemanthele-lessoniana/" lessoniana="" title="Click here to read more on ">
#  <img alt="Anemanthele lessoniana image" src="/assets/Uploads/fce4c8773b/Anemanthele-lessoniana__FillWzQ4MCw2MDBd.JPG"/>
#  </a>,
#  <a apodasmia="" href="/shop/native-plants/apodasmia-similis/" similis="" title="Click here to read more on ">
#  <img alt="Apodasmia similis image" src="/assets/Uploads/552beadd3d/Apodasmia-1Lt__FillWzQ4MCw2MDBd.JPG"/>
#  </a>,
#  <a armeria="" deep="" href="/shop/ornamentals-and-non-native-plants/armeria-morning-star-deep-rose/" morning="" rose="" star="" title="Click here to read more on ">
# ...

# %%
for link in soup.find_all('a', {'title': 'Click here to read more on '}):
    href1 = link.get('href')
    print(href1)
# Out:
# /shop/native-plants/caldcluvia-rosiflora/
# /shop/native-plants/anemanthele-lessoniana/
# /shop/native-plants/apodasmia-similis/
# /shop/ornamentals-and-non-native-plants/armeria-morning-star-deep-rose/
# /shop/native-plants/astelia-nervosa-westland/
# /shop/native-plants/astelia-nervosa-westland/
# /shop/ornamentals-and-non-native-plants/azalea-pax/
# /shop/ornamentals-and-non-native-plants/azalea-pax/
# /shop/ornamentals-and-non-native-plants/buxus-green-gem/
# /shop/ornamentals-and-non-native-plants/buxus-green-gem/
# /shop/ornamentals-and-non-native-plants/buxus-sempervirens/
# /shop/native-plants/carex-comans-green/
# /shop/native-plants/carex-comans-green/
# /shop/native-plants/carex-testacea/
# /shop/native-plants/carex-virgata/
# /shop/native-plants/carpodetus-serratus-prostrata/
# /shop/native-plants/coprosma-black-cloud/
# /shop/native-plants/coprosma-dark-spire/
# /shop/native-plants/coprosma-taiko/
# /shop/native-plants/coprosma-kirkii/
# ...

# %%
href=[]
for each in a:
  href.append(each.get('href'))
href
# Out:
# ['/shop/native-plants/caldcluvia-rosiflora/',
#  '/shop/native-plants/anemanthele-lessoniana/',
#  '/shop/native-plants/apodasmia-similis/',
#  '/shop/ornamentals-and-non-native-plants/armeria-morning-star-deep-rose/',
#  '/shop/native-plants/astelia-nervosa-westland/',
#  '/shop/native-plants/astelia-nervosa-westland/',
#  '/shop/ornamentals-and-non-native-plants/azalea-pax/',
#  '/shop/ornamentals-and-non-native-plants/azalea-pax/',
#  '/shop/ornamentals-and-non-native-plants/buxus-green-gem/',
#  '/shop/ornamentals-and-non-native-plants/buxus-green-gem/',
#  '/shop/ornamentals-and-non-native-plants/buxus-sempervirens/',
#  '/shop/native-plants/carex-comans-green/',
#  '/shop/native-plants/carex-comans-green/',
#  '/shop/native-plants/carex-testacea/',
#  '/shop/native-plants/carex-virgata/',
#  '/shop/native-plants/carpodetus-serratus-prostrata/',
#  '/shop/native-plants/coprosma-black-cloud/',
#  '/shop/native-plants/coprosma-dark-spire/',
# ...

# %%
page2=requests.get(url+href[0])
url+href[0]
# Out:
# 'https://nznativeplantnursery.co.nz/shop//shop/native-plants/caldcluvia-rosiflora/'

# %%
href[0].split("/shop")[1]
# Out:
# '/native-plants/caldcluvia-rosiflora/'

# %%
url+href[0].split("/shop/")[1]
# Out:
# 'https://nznativeplantnursery.co.nz/shop/native-plants/caldcluvia-rosiflora/'

# %%
pageproduct=requests.get(url+href[2].split("/shop/")[1])
pageproduct
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(pageproduct.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Simple. by Sara (saratusar.com, @saratusar) for Innovatif - an awesome Slovenia-based digital agency (innovatif.com/en)
# Change it, enhance it and most importantly enjoy it!
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# -->
# <!--[if !IE]><!-->
# <html lang="en-NZ">
#  <!--<![endif]-->
#  <!--[if IE 6 ]><html lang="en-NZ" class="ie ie6"><![endif]-->
#  <!--[if IE 7 ]><html lang="en-NZ" class="ie ie7"><![endif]-->
#  <!--[if IE 8 ]><html lang="en-NZ" class="ie ie8"><![endif]-->
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-177744059-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
# ...

# %%
title=soup.find('h1',class_="pageTitle")
title.get_text()
# Out:
# 'Apodasmia similis'

# %%
divs=soup.find_all('div', class_="productContent typography")
divs
# Out:
# [<div class="productContent typography">
#  <p>Grows around lakes, ponds, salt marshes. I have also seen it planted in council gardens, like bus stops, parks, and many other places. They have a slight  blue colour to them.</p><p>Prefers moist soil but have also seen it growing in dryer areas.</p><p>These plants are in a 1 Lt container.</p>
#  </div>]

# %%
divs=soup.find_all('div', class_="productContent typography")
divs[0].find('p').get_text()
# Out:
# 'Grows around lakes, ponds, salt marshes. I have also seen it planted in council gardens, like bus stops, parks, and many other places. They have a slight\xa0 blue colour to them.'

# %%
divs=soup.find_all('div', class_="productContent typography")
divs[0].find_all('p')[1].get_text()
# Out:
# 'Prefers moist soil but have also seen it growing in dryer areas.'

# %%
divs=soup.find_all('div', class_="productContent typography")
divs
dd=divs[0].find_all('p')
divs
# Out:
# [<div class="productContent typography">
#  <p>Grows around lakes, ponds, salt marshes. I have also seen it planted in council gardens, like bus stops, parks, and many other places. They have a slight  blue colour to them.</p><p>Prefers moist soil but have also seen it growing in dryer areas.</p><p>These plants are in a 1 Lt container.</p>
#  </div>]

# %%
ctgy=soup.find_all('div', class_="categoryTags")
ctgy
# Out:
# [<div class="categoryTags">
#  <a href="shop/?SearchWetland=1&amp;action_doPlantSearch=Search">Wetland | </a>
#  <a href="shop/?SearchFrostMature=1&amp;action_doPlantSearch=Search">Frost Hardy When Mature | </a>
#  <a href="shop/?SearchDamp=1&amp;action_doPlantSearch=Search">Suits Damp Conditions | </a>
#  <a href="shop/?SearchDry=1&amp;action_doPlantSearch=Search">Suits OpenSunlight | </a>
#  <a href="shop/?SearchDry=1&amp;action_doPlantSearch=Search">Riparian Planting | </a>
#  <a href="shop/?SearchDry=1&amp;action_doPlantSearch=Search">Suits Salt Laden Winds | </a>
#  <a href="shop/?SearchDry=1&amp;action_doPlantSearch=Search">Wetland Species | </a>
#  </div>]

# %%
acat=ctgy[0].select("a")

atext=[]
for e in acat:
    atext.append(e.get_text().strip(" | "))
atext
# Out:
# ['Wetland',
#  'Frost Hardy When Mature',
#  'Suits Damp Conditions',
#  'Suits OpenSunlight',
#  'Riparian Planting',
#  'Suits Salt Laden Winds',
#  'Wetland Species']
